# %% [markdown]
# ## Use a Slider to interactively display channels from 3D cube.
# From http://nbarbey.github.io/2011/07/08/matplotlib-slider.html

# %%
def cube_show_slider(cube, axis=2, **kwargs):
    """
    Display a 3d ndarray with a slider to move along the third dimension.

    Extra keyword arguments are passed to imshow
    """
    import matplotlib.pyplot as plt
    from matplotlib.widgets import Slider, Button, RadioButtons

    # check dim
    if not cube.ndim == 3:
        raise ValueError("cube should be an ndarray with ndim == 3")

    # generate figure
    fig = plt.figure()
    ax = plt.subplot(111)
    fig.subplots_adjust(left=0.25, bottom=0.25)

    # select first image
    s = [slice(0, 1) if i == axis else slice(None) for i in range(3)]
    im = cube[s].squeeze()

    # display image
    l = ax.imshow(im, **kwargs)

    # define slider
    axcolor = 'lightgoldenrodyellow'
    ax = fig.add_axes([0.25, 0.1, 0.65, 0.03], axisbg=axcolor)

    slider = Slider(ax, 'Axis %i index' % axis, 0, cube.shape[axis] - 1,
                    valinit=0, valfmt='%i')

    def update(val):
        ind = int(slider.val)
        s = [slice(ind, ind + 1) if i == axis else slice(None)
                 for i in range(3)]
        im = cube[s].squeeze()
        l.set_data(im, **kwargs)
        fig.canvas.draw()

    slider.on_changed(update)

    plt.show()

# %%
from astropy.io import fits
from spectral_cube import SpectralCube
cube = "../nro_maps/12CO_20161002_FOREST-BEARS_spheroidal_xyb_grid7.5_0.099kms.fits"
spec_cube = SpectralCube.read(cube)
hdu = fits.open(cube)[0]
spec_cube.spectral_axis[18]
# Out:
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'spcfix' made the change 'Changed CTYPE3 from 'VELO-LSR' to 'VOPT', and SPECSYS to 'LSRK''. [astropy.wcs.wcs]
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py:238: UserWarning: radio_beam is not installed. No beam can be created.
#   warnings.warn("radio_beam is not installed. No beam "
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py:246: UserWarning: Could not parse beam information from header.  Exception was: UnboundLocalError("local variable 'Beam' referenced before assignment",)
#   "  Exception was: {0}".format(ex.__repr__()))
# <Quantity -1168.5 m / s>

# %% [markdown]
# ## Use Aplpy with a Slider to make a nicer channel slicer.

# %%
import shells
shell_list = shells.get_shells()
n = 8
shell = shell_list[n]

# %%
from aplpy import FITSFigure
import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.widgets import Slider, Button, RadioButtons


chan = 100

title = "Shell " + str(n+1)
pad_factor = 2.
stretch = 'linear'
ra = shell.ra.value
dec = shell.dec.value
radius = shell.radius.value



#For the auto color scaling to the min and max intensities in the zoomed region.
ra_grid = spec_cube.spatial_coordinate_map[1].to(u.deg).value
dec_grid = spec_cube.spatial_coordinate_map[0].to(u.deg).value
#shell_mask = (ra_grid - ra) ** 2. + (dec_grid - dec) ** 2. < (radius) ** 2.
subcube_mask = (abs(ra_grid - ra) < radius * pad_factor) &\
               (abs(dec_grid - dec) < radius*pad_factor)
sub_cube = spec_cube.with_mask(subcube_mask).minimal_subcube()

#auto color scaling
subcube_pixels = sub_cube[chan].value
vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
print(vmin, vmax)


#center plot on the shell
fig = plt.figure()
subplot = FITSFigure(sub_cube.hdu, figure=fig, slices=[chan], auto_refresh=True)
subplot.set_title(title)
#subplot.recenter(ra, dec, radius*pad_factor)

#Make aplpy grayscale plot with nice color scaling/stretch
subplot.show_grayscale(stretch=stretch, vmin=vmin, vmax=vmax)     

#fig.canvas.draw()
subplot.tick_labels.set_yformat("dd:mm")
subplot.tick_labels.set_xformat("hh:mm")
subplot.tick_labels.set_style('plain')

#Set up slider to change spectral channels.
axcolor = 'lightgoldenrodyellow'
ax = fig.add_axes([0.25, 0.95, 0.65, 0.03], axisbg=axcolor)
slider = Slider(ax, 'Channel', 0, hdu.data.shape[0] - 1,
                    valinit=chan, valfmt='%i')

#button_velmin = ()
#button_velmax = 
#To-Do: Implement buttons that will write out v_min and v_max to a velocity range table.


def update(val):
        ind = int(slider.val)
        
        #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
        #subplot.recenter(ra, dec, radius*pad_factor)
        subplot.image.set_data(sub_cube[ind].hdu.data)
        subcube_pixels = sub_cube[ind].value
        vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
        subplot.image.set_clim(vmin, vmax)
        
        #fig.canvas.draw()
        
        #subplot.show_grayscale(stretch=stretch, vmin=vmin, vmax=vmax)
        #subplot.set_data()
        #fig.canvas.draw()

#def write_velmin():
#    current_chan = int(slider.val)
#def write_velmax():
#    current_chan = inte(slider.val)
    
        
slider.on_changed(update)

button_velmin.on_click(write_velmin)
button_velmax.on_click(write_velmax)

plt.show()
# Out:
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py:238: UserWarning: radio_beam is not installed. No beam can be created.
#   warnings.warn("radio_beam is not installed. No beam "
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py:246: UserWarning: Could not parse beam information from header.  Exception was: UnboundLocalError("local variable 'Beam' referenced before assignment",)
#   "  Exception was: {0}".format(ex.__repr__()))
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'spcfix' made the change 'Changed CTYPE3 from 'VELO-LSR' to 'VOPT', and SPECSYS to 'LSRK''. [astropy.wcs.wcs]
# WARNING: A 'NAXIS1' keyword already exists in this header.  Inserting duplicate keyword. [astropy.io.fits.header]
# WARNING: A 'NAXIS3' keyword already exists in this header.  Inserting duplicate keyword. [astropy.io.fits.header]
# 12.7157 26.7037
# //anaconda/lib/python3.4/site-packages/matplotlib/artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mousePressEvent(self, event)
#     257         if button is not None:
#     258             FigureCanvasBase.button_press_event(self, x, y, button,
# --> 259                                                 guiEvent=event)
#     260         if DEBUG:
#     261             print('button pressed:', event.button())
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in button_press_event(self, x, y, button, dblclick, guiEvent)
#    1901         mouseevent = MouseEvent(s, self, x, y, button, self._key,
#    1902                                 dblclick=dblclick, guiEvent=guiEvent)
# -> 1903         self.callbacks.process(s, mouseevent)
#    1904
#    1905     def button_release_event(self, x, y, button, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 5185 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 5130 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 5295 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 5405 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 5460 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 5625 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 5735 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 5790 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 6010 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 6065 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mousePressEvent(self, event)
#     257         if button is not None:
#     258             FigureCanvasBase.button_press_event(self, x, y, button,
# --> 259                                                 guiEvent=event)
#     260         if DEBUG:
#     261             print('button pressed:', event.button())
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in button_press_event(self, x, y, button, dblclick, guiEvent)
#    1901         mouseevent = MouseEvent(s, self, x, y, button, self._key,
#    1902                                 dblclick=dblclick, guiEvent=guiEvent)
# -> 1903         self.callbacks.process(s, mouseevent)
#    1904
#    1905     def button_release_event(self, x, y, button, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 6999 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# ...
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 362 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 407 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 499 is out of bounds for axis 0 with size 232
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# //anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_qt5.py in mouseMoveEvent(self, event)
#     277         # flipy so y=0 is bottom of canvas
#     278         y = self.figure.bbox.height - event.y()
# --> 279         FigureCanvasBase.motion_notify_event(self, x, y, guiEvent=event)
#     280         # if DEBUG: print('mouse move')
#     281
#
# //anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in motion_notify_event(self, x, y, guiEvent)
#    1950         event = MouseEvent(s, self, x, y, self._button, self._key,
#    1951                            guiEvent=guiEvent)
# -> 1952         self.callbacks.process(s, event)
#    1953
#    1954     def leave_notify_event(self, guiEvent=None):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# //anaconda/lib/python3.4/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in _update(self, event)
#     432             val = self.slidermax.val
#     433
# --> 434         self.set_val(val)
#     435
#     436     def set_val(self, val):
#
# //anaconda/lib/python3.4/site-packages/matplotlib/widgets.py in set_val(self, val)
#     446             return
#     447         for cid, func in six.iteritems(self.observers):
# --> 448             func(val)
#     449
#     450     def on_changed(self, func):
#
# <ipython-input-99-8968a4c49f33> in update(val)
#      58         #subplot = FITSFigure(hdu, figure=fig, slices=[chan], auto_refresh=True)
#      59         #subplot.recenter(ra, dec, radius*pad_factor)
# ---> 60         subplot.image.set_data(sub_cube[ind].hdu.data)
#      61         subcube_pixels = sub_cube[ind].value
#      62         vmin, vmax = np.nanmin(subcube_pixels), np.nanmax(subcube_pixels)
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in __getitem__(self, view)
#    1067                 header['CUNIT3'] = self._spectral_unit.to_string(format='FITS')
#    1068
# -> 1069             return Slice(value=self.filled_data[view],
#    1070                          wcs=newwcs,
#    1071                          copy=False,
#
# /Users/jesse/carma/spectral-cube/spectral_cube/cube_utils.py in __getitem__(self, view)
#     199
#     200     def __getitem__(self, view):
# --> 201         return self._func(self._other, view)
#     202
#     203     def __iter__(self):
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in filled_data(self, view)
#    1111             The masked data.
#    1112         """
# -> 1113         return u.Quantity(self._get_filled_data(view, fill=self._fill_value),
#    1114                           self.unit, copy=False)
#    1115
#
# /Users/jesse/carma/spectral-cube/spectral_cube/spectral_cube.py in _get_filled_data(self, view, fill, check_endian)
#    1188
#    1189         return self._mask._filled(data=data, wcs=self._wcs, fill=fill,
# -> 1190                                   view=view, wcs_tolerance=self._wcs_tolerance)
#    1191
#    1192     @cube_utils.slice_syntax
#
# /Users/jesse/carma/spectral-cube/spectral_cube/masks.py in _filled(self, data, wcs, fill, view, **kwargs)
#     183         # type otherwise
#     184         dt = np.find_common_type([data.dtype], [np.float])
# --> 185         sliced_data = data[view].astype(dt)
#     186         ex = self.exclude(data=data, wcs=wcs, view=view, **kwargs)
#     187         sliced_data[ex] = fill
#
# IndexError: index 499 is out of bounds for axis 0 with size 232

# %%
subplot.image.set_clim?
